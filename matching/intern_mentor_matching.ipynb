# %%
import pandas as pd

# %%
feature_columns = feature_columns = [
    'School',
    'Major',
    'Year',
    'Firms',
    'Roles',
]

def normalize(df):
    for feature in feature_columns:
        if feature == 'Year':
            continue
        df[feature] = df[feature].str.upper()
        df[feature] = df[feature].str.strip()
    return df

mentees_df = normalize(pd.read_csv('mentees.csv'))
mentors_df = normalize(pd.read_csv('mentors.csv'))

# %%
def compare_school(mentor, mentee):
    if mentor['School'] == mentee['School']:
        return 0
    return 3

def compare_major(mentor, mentee):
    if mentor['Major'] == mentee['Major']:
        return 0
    if "Computer Science" in [mentor['Major'], mentee['Major']]:
        return 5
    return 10  # if majors are different and neither is Computer Science

def compare_year(mentor, mentee):
    gap = int(mentor['Year']) - int(mentee['Year'])
    if gap < 0:
        # don't allow mentee older than mentor
        return 1000
    elif gap <= 2:
        return 0
    else:
        # slightly prefer smaller gaps
        return 2

def compare_firms(mentor, mentee):
    mentee_firms = set(mentee['Firms'].split(', '))
    mentor_firms = set(mentor['Firms'].split(', '))
    diff = mentee_firms.difference(mentor_firms)
    return 5 * min(3, len(diff))

def compare_roles(mentor, mentee):
    mentee_roles = set(mentee['Roles'].split(', '))
    mentor_roles = set(mentor['Roles'].split(', '))
    diff = mentee_roles.difference(mentor_roles)
    return 5 * min(3, len(diff))

def similarity(mentor, mentee):
    return compare_school(mentor, mentee) + \
           compare_major(mentor, mentee) + \
           compare_year(mentor, mentee) + \
           compare_firms(mentor, mentee) + \
           compare_roles(mentor, mentee)

# %% [markdown]
# After accounting for mentee preferences, not all mentees were allocated.
#
# - Undersubscibed mentors (mentees that indicated preference for them < maximum number of mentees the mentor is willing to take)
# - Mentees who did not fill in the preference form
#
# The goal of `recommend_mentors` is to generate mentor recommendations such that:
#
# - Every available mentor is recommended to at least one mentee.
# - Every uncovered mentee receives exactly two mentor options.
# - A mentee is never recommended the same mentor twice.
# - Recommendation load is distributed fairly across mentors.
# - Recommendations are still based on mentor–mentee similarity.
#
# This algorithm takes 2 passes:
#
# ### Pass 1: Cover all mentors
# - Compute the similarity score between every mentor and every mentee.
# - Run the Hungarian algorithm to find the minimum-cost assignment.
# - Assign each mentor to exactly one mentee.
# - Every mentor is recommended at least once.
# - Some mentees now have one recommendation; others have none.
#
# ### Pass 2: Fill remaining mentee slots
#
# - Pick a mentee that still needs recommendations.
# - Among mentors that are not already assigned to that mentee, and have remaining capacity, choose the mentor with the best similarity score.
# - Add that recommendation and update mentor load.
# - Continue until every mentee has two recommendations.

# %%
from collections import defaultdict
from munkres import Munkres

import numpy as np
import pandas as pd


def recommend_mentors(
    mentors_df: pd.DataFrame,
    mentees_df: pd.DataFrame,
    similarity_func,
):
    mentors = mentors_df.index.tolist()
    mentees = mentees_df.index.tolist()

    assignments = defaultdict(set)
    mentor_load = defaultdict(int)

    #
    # PASS 1
    # Every mentor gets exactly one mentee
    #

    cost_matrix = []

    for mentor_id, mentor in mentors_df.iterrows():
        row = []

        for mentee_id, mentee in mentees_df.iterrows():
            row.append(similarity_func(mentor, mentee))

        cost_matrix.append(row)

    matching = Munkres().compute(cost_matrix)

    for mentor_idx, mentee_idx in matching:
        mentor = mentors[mentor_idx]
        mentee = mentees[mentee_idx]

        assignments[mentee].add(mentor)
        mentor_load[mentor] += 1

    #
    # Target capacities
    #

    total_recommendations = len(mentees) * 2

    base = total_recommendations // len(mentors)
    extra = total_recommendations % len(mentors)

    capacities = {}

    for i, mentor in enumerate(mentors):
        capacities[mentor] = base + (1 if i < extra else 0)

    #
    # PASS 2
    #
    # Fill mentees until everyone has 2 mentors.
    #

    while True:
        deficits = {
            mentee: 2 - len(assignments[mentee])
            for mentee in mentees
        }

        remaining = sum(deficits.values())

        if remaining == 0:
            break

        # Choose a mentee that still needs mentors
        mentee = max(deficits, key=deficits.get)

        if deficits[mentee] == 0:
            break

        mentee_data = mentees_df.loc[mentee]

        best_mentor = None
        best_score = float("inf")

        for mentor in mentors:
            if mentor in assignments[mentee]:
                continue

            if mentor_load[mentor] >= capacities[mentor]:
                continue

            score = similarity_func(
                mentors_df.loc[mentor],
                mentee_data,
            )

            if score < best_score:
                best_score = score
                best_mentor = mentor

        if best_mentor is None:
            raise RuntimeError(
                f"Could not find mentor for mentee {mentee}"
            )

        assignments[mentee].add(best_mentor)
        mentor_load[best_mentor] += 1

    #
    # Build mentee view
    #

    recommendations_by_mentee = pd.DataFrame(
        index=mentees,
        columns=["Mentor 1", "Mentor 2"],
        dtype=object,
    )

    for mentee in mentees:
        assigned = list(assignments[mentee])

        recommendations_by_mentee.loc[mentee] = assigned

    #
    # Build mentor view
    #

    mentor_to_mentees = defaultdict(list)

    for mentee in mentees:
        for mentor in assignments[mentee]:
            mentor_to_mentees[mentor].append(mentee)

    max_load = max(len(v) for v in mentor_to_mentees.values())

    recommendations_by_mentor = pd.DataFrame(
        index=mentors,
        columns=[f"Mentee {i+1}" for i in range(max_load)],
        dtype=object,
    )

    for mentor in mentors:
        mentee_list = mentor_to_mentees[mentor]

        recommendations_by_mentor.loc[
            mentor,
            recommendations_by_mentor.columns[:len(mentee_list)]
        ] = mentee_list

    recommendation_count = pd.Series(
        {mentor: len(mentor_to_mentees[mentor]) for mentor in mentors},
        name="recommendation_count",
    )

    return (
        recommendations_by_mentor,
        recommendations_by_mentee,
        recommendation_count,
    )

# %%
recommendations_by_mentor, recommendations_by_mentee, recommendation_count, = recommend_mentors(mentors_df, mentees_df, similarity)

# %%
recommendations_by_mentee

# %%
recommendation_count

# %%
recommendations_by_mentee.to_csv("recommendations_by_mentee")
